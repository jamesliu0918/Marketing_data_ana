# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import sklearn
import numpy as np

# %%
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species_dummies']  =  df['Species'].apply(lambda x :  0 if x =='Iris-setosa'  else 1 if x =='Iris-versicolor' else 2)

# %%
df_setosa =  df.groupby('Species')['SepalLengthCm','PetalLengthCm'].mean()
df_setosa
# Out:
# C:\Users\JamesLiu\AppData\Local\Temp\ipykernel_7000\1221424263.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_setosa =  df.groupby('Species')['SepalLengthCm','PetalLengthCm'].mean()
#                  SepalLengthCm  PetalLengthCm
# Species
# Iris-setosa              5.006          1.464
# Iris-versicolor          5.936          4.260
# Iris-virginica           6.588          5.552

# %%
df_pt  = pd.pivot_table(df,     values=['PetalLengthCm', 'SepalLengthCm'], index = 'Species' )
#      = pd.pivot_table(b_data, values='age', index='marital', columns='conversation', aggfunc=len)
df_pt
# Out:
#                  PetalLengthCm  SepalLengthCm
# Species
# Iris-setosa              1.464          5.006
# Iris-versicolor          4.260          5.936
# Iris-virginica           5.552          6.588

# %%
dummy  =  pd.get_dummies(df['Species'])
dummy.columns = ['Species_%s' % x for x in dummy.columns]
dummy
# Out:
#      Species_Iris-setosa  Species_Iris-versicolor  Species_Iris-virginica
# 0                      1                        0                       0
# 1                      1                        0                       0
# 2                      1                        0                       0
# 3                      1                        0                       0
# 4                      1                        0                       0
# ..                   ...                      ...                     ...
# 145                    0                        0                       1
# 146                    0                        0                       1
# 147                    0                        0                       1
# 148                    0                        0                       1
# 149                    0                        0                       1
#
# [150 rows x 3 columns]

# %%
df = pd.concat([df,dummy], axis = 1)

# %%
from sklearn import tree
import graphviz

# %%
dt_model = tree.DecisionTreeClassifier(
    max_depth=4
)

# %%
feature = ['SepalLengthCm' , 'SepalWidthCm','PetalLengthCm','PetalWidthCm']

# %%
y = ['Species_dummies']

# %%
dt_model.fit(df[feature],df[y])
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
dot_data = tree.export_graphviz(
    dt_model, 
    out_file=None, 
    feature_names=feature,  
    class_names=['Iris-setosa', 'Iris-virginica','Iris-versicolor'],   
    filled=True,     # 貌似是標示出
    rounded= True,   # 讓角變圓
    special_characters=True
) 
graph = graphviz.Source(dot_data)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>text {font-size: 10px;}</style>"))
graph
# Out:
# C:\Users\JamesLiu\AppData\Local\Temp\ipykernel_7000\527908064.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>text {font-size: 10px;}</style>

# %% [markdown]
# 嘗試改變 Species 的號碼

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species_dummies2']  =  df['Species'].apply(lambda x :  0 if x =='Iris-setosa'  else 1 if x =='Iris-virginica' else 3)

# %%
y2 = ['Species_dummies2']

# %%
dt_model.fit(df[feature],df[y2])
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
dot_data = tree.export_graphviz(
    dt_model, 
    out_file=None, 
    feature_names=feature,  
    class_names=['Iris-setosa', 'Iris-virginica','Iris-versicolor'],   
    filled=True,     # 貌似是標示出
    rounded= True,   # 讓角變圓
    special_characters=True
) 
graph = graphviz.Source(dot_data)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>text {font-size: 10px;}</style>"))
graph
# Out:
# C:\Users\JamesLiu\AppData\Local\Temp\ipykernel_7000\527908064.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>text {font-size: 10px;}</style>
